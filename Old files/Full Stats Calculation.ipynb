# %%
# !pip install tslearn
import pandas as pd
from datetime import datetime
#import dateparser
import numpy as np
from tqdm.notebook import tqdm
import os
import json
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
import numpy as np
import matplotlib.pylab as pylab
import matplotlib.patches as patches
import pickle as pkl
from tslearn.clustering import TimeSeriesKMeans
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 793 kB 7.3 MB/s
# ...

# %%
DATASET_PATH = '/content/drive/MyDrive/Project/AzureDataset_FunctionCalls/'
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
summerino = 0
lenSum = 0
testss = []
for d in range(0,2):
  with open(f'/content/drive/MyDrive/Project/AzureDataset_FunctionCalls/Stored_Analyzer_Data/testss{d}.txt', 'rb') as fp:
    testss.append(pkl.load(fp))
  summerino += sum(testss[d][10])
  lenSum += len(testss[d][10])
print('Average: ', summerino/lenSum)
# Out:
# Average:  0.9824574511315377

# %%
test = testss[d][10]
print(sum(test)/len(test))
# Out:
# 0.9817179861021486
